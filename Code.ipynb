# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
df=pd.ExcelFile("dataset.xlsx")
pd.options.display.max_columns = None
pd.options.display.max_rows = None

df.sheet_names
# Out:
# ['diary_study-entries-2023-01-19_',
#  'P1',
#  'P2',
#  'P3',
#  'P4',
#  'P5',
#  'P6',
#  'DRAFT']

# %%
df=pd.read_excel(df,df.sheet_names[0])

# %%
df.head()
# Out:
#    Scout ID  Age Gender  State  Postal Code         Country   Education Level  \
# 0   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 1   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 2   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 3   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 4   1683443   59    man    NaN          NaN  United Kingdom  College graduate
#
#   Employment Status  Ethnicity Household Composition Household Income  \
# 0           Retired        NaN                   NaN              NaN
# 1           Retired        NaN                   NaN              NaN
# 2           Retired        NaN                   NaN              NaN
# 3           Retired        NaN                   NaN              NaN
# 4           Retired        NaN                   NaN              NaN
#
#   Job Title Industry  Research Industry Mobile Device  Entry ID  Part  \
# ...

# %%
df.columns
# Out:
# Index(['Scout ID', 'Age', 'Gender', 'State', 'Postal Code', 'Country',
#        'Education Level', 'Employment Status', 'Ethnicity',
#        'Household Composition',
#        ...
#        'P6:Q4: Okay, it's time to write your "love letter"! What do you want Pollypocket to know? What are the *best things about tracking your sleep with Pollypocket*? What would you compliment your Pollypocket on when it comes to tracking your sleep? Please be as descriptive as possible, and write your answer in letter format!',
#        'P6:Q6: Give your breakup letter a brief one-sentence "title"! Use the format "Dear Pollypocket, _______."',
#        'P6:Q7: Respond in 3 words or short phrases: What I dislike about tracking sleep with Pollypocket is ______, ______, and ______.',
# ...

# %%
df.head()
# Out:
#    Scout ID  Age Gender  State  Postal Code         Country   Education Level  \
# 0   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 1   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 2   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 3   1683443   59    man    NaN          NaN  United Kingdom  College graduate
# 4   1683443   59    man    NaN          NaN  United Kingdom  College graduate
#
#   Employment Status  Ethnicity Household Composition Household Income  \
# 0           Retired        NaN                   NaN              NaN
# 1           Retired        NaN                   NaN              NaN
# 2           Retired        NaN                   NaN              NaN
# 3           Retired        NaN                   NaN              NaN
# 4           Retired        NaN                   NaN              NaN
#
#   Job Title Industry  Research Industry Mobile Device  Entry ID  Part  \
# ...

# %%
df.shape
# Out:
# (306, 199)

# %%
df.value_counts("P1:Q1: Remind us - which of the following do you currently use to track your sleep? Select all that apply. (Freestanding alarm clock (i.e., not an app))")
# Out:
# P1:Q1: Remind us - which of the following do you currently use to track your sleep? Select all that apply. (Freestanding alarm clock (i.e., not an app))
# Freestanding alarm clock (i.e., not an app)    1
# dtype: int64

# %% [markdown]
# ### Question # 1

# %% [markdown]
# #### How do user see/view sleep?

# %%
df.value_counts("P1:Q5: Next, weâ€™re going to ask you some general questions about your sleep habits and experiences. On average, you would say that your quality of sleep isâ€¦").plot(kind='bar',title='Quality of sleep user take',xlabel='')
# Out:
# <AxesSubplot:title={'center':'Quality of sleep user take'}>

# %% [markdown]
# ###### In this user is asked to tell their viewpoint about sleep and quality of sleep they take usually and it was found that most of peoples have sleep quality lies in the category of "Okay" and "Good" while their are few peoples who have "excellent" and "bad" quality of sleep.

# %% [markdown]
# #### Factor Effect the Sleep

# %%
fig, axes=plt.subplots(5,2)
fig.suptitle("What factors influence your quality of sleep most?")
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Outdoor environment (e.g., outdoor light, weather, air quality))").plot(kind='bar', ax=axes[0,0],xlabel='',title='Outdoor environment')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Consumption of food/drink/medication (e.g., caffeine, antihistamine))").plot(kind='bar', ax=axes[0,1],xlabel='',title='Consumption of food')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Others in my home (e.g., pets, children))").plot(kind='bar',ax=axes[1,0],xlabel='',title='Others in my home')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Tech devices (e.g., cell phone usage, white noise machine))").plot(kind='bar',ax=axes[1,1],xlabel='',title='Tech devices')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Personal health/wellness (e.g., stuffy nose))").plot(kind='bar',ax=axes[2,0],xlabel='',title='Personal health')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Pre-bedtime activities (e.g., reading a book, talking on the phone))").plot(kind='bar',ax=axes[2,1],xlabel='',title='Pre-bedtime activities ')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Time I woke up this morning)").plot(kind='bar',ax=axes[3,0],xlabel='',title='Time wake up')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Time I am going to bed)").plot(kind='bar',ax=axes[3,1],xlabel='',title='Time for bed')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Time I need to wake up tomorrow)").plot(kind='bar',ax=axes[4,0],xlabel='',title='Time wake up')
df.value_counts("P1:Q6: What factors influence your quality of sleep most? Rank them, beginning with 1 = most influential. If a factor doesnâ€™t impact your sleep, select â€˜N/A.â€™ (Other (Tap to Type)).1").plot(kind='bar',ax=axes[4,1],xlabel='',title='Other')
fig.tight_layout()

# %% [markdown]
# ###### if we look at factor affecting quality of sleep then above cell shows that it highly depend on following then
#  - Consumption of food
#  - Use of Tech devices before sleep
#  - Other in my home
#  - Outdoor environment

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### How do users approach their sleep patterns

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Experience with sleep / sleep adjustment / sleep tracking

# %%
df.value_counts("P1:Q8: Overall, how would you rate the *usefulness* of sleep tracking for you personally?").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### the above cell show that how user take to track a sleep and it was that most of the people agree that it is extremley useful for us and there is not a single statement that will tell they are disagree with traccking the sleep

# %%
df.value_counts("P1:Q9: Why are you primarily tracking sleep?").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Answering the tracking sleep question, one question is why you track your sleep and most of the user says they want to change the habit and other possible option said are "maintaing current habit" and "out of genral interest"

# %%
df.value_counts("P1:Q12: Since you first started tracking your sleep, how would you rate your level of consistency?").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Third question is knowing the consistency of tracking the sleep and it was found that most people agree that they track the sleep same has they did first time and they option at seconds says that track much more than i did first time.

# %%
df.value_counts("P1:Q14: How much, if at all, has tracking your sleep led you to change your behavior when it comes to sleep?").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### last question in tracking speed is that how much it change behavior of user after tracking and it was found that siginificant change is noted for most of the people who track their sleep while noting that there are only few who are saying that they noted minimal chnage
#
# #### Overall, user take it positive to track a sleep they think that will help them in maintianing and changing theiur habits of sleep and will be affect in taking sound sleep

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### How do user interact with devices in the context of their sleep

# %%
x=df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (I received it as a gift)")
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (I wanted to track my sleep)"))
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (I was interested in tracking my overall fitness or wellbeing)"))
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (I wanted to improve my sleep)"))
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (It was recommended by a friend or family member)"))                           
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (It was recommended by a physician or other health professional)"))
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (I was curious about the product, but did not have a specific reason)"))
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (The price was appealing)"))
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (I wanted a smartwatch)"))
x=x.append(df.value_counts("P1:Q2: How/why did you acquire a sleep tracking device(s)/app(s)? Select all that apply. (Other (Tap to Type))"))

# %%
x.plot(kind='bar',title="how did people acquire tracking device for sleep?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10200\2983611916.py in <module>
# ----> 1 x.plot(kind='bar',title="how did people acquire tracking device for sleep?")
#
# NameError: name 'x' is not defined

# %% [markdown]
# ##### It was seen that people acquire devices because of following reasons
# ##### - tell heart rate during sleep
# ##### - Sleep score detail
# ##### - % restlessness

# %%
df.value_counts("P1:Q12: Since you first started tracking your sleep, how would you rate your level of consistency?").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Second question is knowing the consistency of tracking the sleep and it was found that most people agree that they track the sleep same has they did first time and they option at seconds says that track much more than i did first time.

# %%
df.value_counts("P1:Q14: How much, if at all, has tracking your sleep led you to change your behavior when it comes to sleep?").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #####  last question in tracking sleep is that how much it change behavior of user after tracking and it was found that siginificant change is noted for most of the people who track their sleep while noting that there are only few who are saying that they noted minimal chnage

# %% [markdown]
# ### Question 5

# %% [markdown]
# #### How would pollypocket comapre to other competitive offering?

# %%
df.value_counts("P2:Q11: Which of the following best describes the role your Pollypocket played in your bedtime routine today?").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### In this importance  of pollypocket during sleep is discussed and it was found that "moderately important" is the category that will be mostly selected as a review from user and very few people select the category of "extremely important"

# %%
df.value_counts("P4:Q1: On a scale of 1-10, how closely did your expectations of the role your Pollypocket would play in your sleep routine match with your actual use? (1=not at all, 10=exactly as expected)").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### If we look at how much pollypocket close to user expectation then it was found very few user told that it was exactly as it was expected by using 10 value in scale of 10 while
# ##### the good news is that most of the user select 8 on sclae of 10

# %% [markdown]
# ### Question 6

# %% [markdown]
# #### How do users interact with current features? how do they interact with sleep features

# %%
x=df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Exploring the menus on my Pollypocket device)")
x=x.append(df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Exploring my Pollypocket app)"))
x=x.append(df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Discussing features with friends)"))
x=x.append(df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Hearing about features online through social media)"))
x=x.append(df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Searching online for new features)"))
x=x.append(df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Advertisements)"))
x=x.append(df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Emails sent to me from Pollypocket)"))
x=x.append(df.value_counts("P4:Q3: How do you find out about new Pollypocket features? Select all that apply. (Other (Tap to Type))"))

# %%
x.plot(kind='bar',title="how do user interact with current features")
# Out:
# <AxesSubplot:title={'center':'how do user interact with current features'}>

# %% [markdown]
# ##### It can be seen  by above picture that  there are following thing by which were come to interact with pollypocket:
# ##### - exploring the menu on my pollypocket device
# ##### - exploring my pollypocket app
# ##### - Discussing features with friends
# ##### - Email sent to me from pollypocket

# %% [markdown]
# ### Question 7

# %% [markdown]
# #### What features/information in the app do user prefer the most?

# %%
df.value_counts("P3:Q9: Choose one data point that you think is most helpful to view about your last sleep session.").plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### In question to which features in the app do user prefer the  most.these are they following feature which are liked by user most:
# ##### - Total sleep duration
# ##### - Sleep Score
# ##### - Amount of deep sleep

# %% [markdown]
# ### Question 8

# %% [markdown]
# #### What make features preferred? what makes features good or wanted?

# %% [markdown]
# ### Question 9

# %% [markdown]
# #### Which features/information in the app do user prefer most?

# %% [markdown]
# ### Question 10

# %% [markdown]
# #### Which features and information in the app do user prefer the least

# %%
x=df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (Sleep Score Details (breakdown of cumulative sleep score into 3 sub-scores))")
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (Snore & Noise Detect)"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (Heart Rate during Sleep)"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (% Restlessness (tossing & turning))"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (â€œGet More Sleepâ€ Guided Program)"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (SpO2 Graph (in the Health Metrics Dashboard))"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (None of the Above)"))
x.plot(kind='bar',title="What make features preferred")
# Out:
# <AxesSubplot:title={'center':'What make features preferred'}>

# %% [markdown]
# ##### It was seen that people use these following  features most
# ##### - tell heart rate during sleep
# ##### - Sleep score detail
# ##### - % restlessness

# %% [markdown]
# #### Which features you want to add on pollypocket

# %%
df.value_counts("P4:Q12: In the context of tracking your sleep, if you could take features from other devices, tools or apps and add them to your Pollypocket, what would they be?")
# Out:
# P4:Q12: In the context of tracking your sleep, if you could take features from other devices, tools or apps and add them to your Pollypocket, what would they be?
# ...

# %% [markdown]
# ##### The user want folliwng features to add in the pollypocket
# ##### - There might be alarm in app
# ##### - there must be diet encouraging app
# ##### - Track movement during sleep
# ##### - Must have messaging platform
# ##### - Sensor to calculate sleep time automatically

# %% [markdown]
# ### Question 11

# %% [markdown]
# #### Why are those features not wanted?

# %% [markdown]
# #### Question 12

# %% [markdown]
# #### How do user feels about features

# %%
df.value_counts("P4:Q11: In an ideal world, when it comes to sleep features, what would your Pollypocket be able to do?")
# Out:
# P4:Q11: In an ideal world, when it comes to sleep features, what would your Pollypocket be able to do?
# Accurately show maybe in a chart form and incorporate with diet apps                                                                                                                                                                                                                                                                                                                                                                        1
# Be more consistent about the Sleeping data, sometimes I do argue if there is consistency in sleeping data.                                                                                                                                                                                                                                                                                                                                  1
# ...

# %% [markdown]
# ##### The suer feeling about current features is
# ##### - contain accurate data
# ##### - help to block out any noise
# ##### - help me in sleeping and waking naturally
# ##### - would not have enough to pay for priemier package

# %% [markdown]
# ### Question 14

# %% [markdown]
# #### Motivations to track sleep

# %%
df.value_counts('P3:Q3: How did this sleep compare to a â€˜typicalâ€™/average sleep for you?').plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### if we look at sleep caompare to average sleep it was found that mostly people say that they have about average sleep taken and other option are
# ##### - somewhat better than average
# ##### - much better than average

# %%
df.value_counts('P3:Q11: Rate your level of agreement with the following statement:Â\xa0\n\n_My Pollypocket sleep score accurately reflects my most recent sleep._').plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### If we look at rate of agreement that the pollypocket hase sleep score accurate itwas found
# ##### - mostly people lies in category of "mostly agree"
# ##### - very few people agree lies in "neither agree nor disagree"

# %% [markdown]
# ### Question 15

# %% [markdown]
# ####  Motivation to use pollypocket's sleep features?

# %%
df.value_counts('P3:Q12: Rate your level of agreement with the following statement:Â\xa0\n\n_Iâ€™m glad I know what my Pollypocket sleep score was for my last sleep session._').plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #####  Agreement to statement that pollypocket sleep of last session, it was found that
# ##### - most peoples mostly agree with statement
# ##### - there were very few peoples that neither agree nor disagree

# %%
df.value_counts('P3:Q7: Remind us â€” did you use any tech devices to track/monitor your sleep session? Select all that apply, if any.').plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Answering to question that which device they use to tracj tehir sleep and it was found that
# ##### - most of peoples use pollypocket device
# ##### - Most use pollypocket app for their sleep
# ##### resultantly it shows that their are most people who are motivated to use pollypicket because of its sleep accuracy feactures

# %% [markdown]
# ### Question 16

# %% [markdown]
# #### Motivations to use/not use premium?

# %%
x=df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (Sleep Score Details (breakdown of cumulative sleep score into 3 sub-scores))")
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (Snore & Noise Detect)"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (Heart Rate during Sleep)"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (% Restlessness (tossing & turning))"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (â€œGet More Sleepâ€ Guided Program)"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (SpO2 Graph (in the Health Metrics Dashboard))"))
x=x.append(df.value_counts("P4:Q9: What sleep features, _currently_, if any, are key factors for why you maintain your subscription to Premium? (None of the Above)"))
x.plot(kind='bar',title="Motivation give to take premier account")
# Out:
# <AxesSubplot:title={'center':'Motivation give to take premier account'}>

# %% [markdown]
# ##### Answering to question that what are motivation that pushes user to take premier package of pollypocket
# ##### - Sleep score detail like brea down into different sub category
# ##### - heart rate in premier package
# ##### - % restlessness

# %% [markdown]
# ### Question 17

# %% [markdown]
# #### Why would users choose pollypockets

# %%
df.value_counts('P3:Q11: Rate your level of agreement with the following statement:Â\xa0\n\n_My Pollypocket sleep score accurately reflects my most recent sleep._').plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %%
df.value_counts('P3:Q12: Rate your level of agreement with the following statement:Â\xa0\n\n_Iâ€™m glad I know what my Pollypocket sleep score was for my last sleep session._').plot(kind='bar',xlabel='')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Why would user choose pollypocket it was found because
# ##### - Most user completely agree with the pollypocket performance
# ##### - Most user agree with their sleep maintaince and habit change feature by pollypocket
# ##### - Most people think that pollypocket help  them to maintain their sleep and wake time and more importantly in changing habit of sleep
